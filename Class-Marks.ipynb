# %% [markdown]
# # Name     :P.NARENDER
# # Roll No. :2211CS010322
# # Group    :4 (3rd year)

# %%
import pandas as pd
df = pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %% [markdown]
# # Importing pandas and reading data from CSV file

# %%
#Labelling qus by adding sub-qus into single column name
df['Qus1'] = df['Q1aM4'] + df['Q1bM6']
df['Qus2'] = df['Q2aM6'] + df['Q2bM4']
df['Qus3'] = df['Q3aM5'] + df['Q3bM5']
df['Qus4'] = df['Q4aM3'] + df['Q4bM7']
df['Qus5'] = df['Q5M10']
df['Qus6'] = df['Q6aM4'] + df['Q6bM6']

df.drop(['Q1aM4', 'Q1bM6', 'Q2aM6', 'Q2bM4', 'Q3aM5', 'Q3bM5', 'Q4aM3', 'Q4bM7', 'Q5M10', 'Q6aM4', 'Q6bM6'], axis=1, inplace=True)
df.head()
# Out:
#    Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 0     37   9.0  10.0   3.0   NaN   8.0  10.0
# 1     32   7.0   7.0   NaN   9.0   9.0   NaN
# 2     33   9.0   6.0  10.0   NaN   8.0   NaN
# 3     24  10.0   9.0   4.0   NaN   NaN   NaN
# 4     36   9.0   8.0   9.0   NaN  10.0   NaN

# %% [markdown]
# # Creating new columns for questions and dropping old ones for the easy analysis of data

# %%
#Finding top 5 members for each question
top_5_per_question = {}
for column in df.columns[1:]:
    top_5_per_question[column] = df.nlargest(5, column)
print(top_5_per_question["Qus1"])
print(top_5_per_question["Qus2"])
print(top_5_per_question["Qus3"])
print(top_5_per_question["Qus4"])
print(top_5_per_question["Qus5"])
print(top_5_per_question["Qus6"])
# Out:
#     Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 3      24  10.0   9.0   4.0   NaN   NaN   NaN
# 5      20  10.0  10.0   NaN   NaN   NaN   NaN
# 7      34  10.0  10.0   NaN   NaN   NaN   NaN
# 14     30  10.0   8.0   9.0   NaN   NaN   NaN
# 21     34  10.0   8.0  10.0   NaN   NaN   NaN
#     Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 0      37   9.0  10.0   3.0   NaN   8.0  10.0
# 5      20  10.0  10.0   NaN   NaN   NaN   NaN
# 7      34  10.0  10.0   NaN   NaN   NaN   NaN
# 10     37   8.0  10.0   NaN   9.0   NaN  10.0
# 13     32   6.0  10.0   8.0   NaN   9.0   NaN
#     Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 2      33   9.0   6.0  10.0   NaN   8.0   NaN
# 6      25   7.0   NaN  10.0   NaN   6.0   NaN
# 9      35   6.0   9.0  10.0   NaN   NaN  10.0
# 15     32   NaN   3.0  10.0  10.0   NaN  10.0
# 20     29   8.0   4.0  10.0   NaN   7.0   NaN
#     Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 15     32   NaN   3.0  10.0  10.0   NaN  10.0
# ...

# %% [markdown]
# # Finding top 5 scores per question and displaying results which is useful for identifyong how the students were addressing questions as of from each topic

# %%
#Missing values for each Question
df.isnull().sum()
# Out:
# Total     0
# Qus1     13
# Qus2     16
# Qus3     39
# Qus4     64
# Qus5     30
# Qus6     60
# dtype: int64

# %% [markdown]
# # Counting the number of null values in each column which is esential for analysing which question is not attempted by many students, that helps in analyzing which topic furthur needed to be discussed.

# %%
#Filling the missing values
df.fillna(df.mean(), inplace=True)
df
# Out:
#     Total       Qus1  Qus2       Qus3      Qus4  Qus5       Qus6
# 0      37   9.000000  10.0   3.000000  7.590909   8.0  10.000000
# 1      32   7.000000   7.0   8.489362  9.000000   9.0   8.769231
# 2      33   9.000000   6.0  10.000000  7.590909   8.0   8.769231
# 3      24  10.000000   9.0   4.000000  7.590909   8.0   8.769231
# 4      36   9.000000   8.0   9.000000  7.590909  10.0   8.769231
# ..    ...        ...   ...        ...       ...   ...        ...
# 81     32   9.000000   7.0   8.000000  7.590909   8.0  10.000000
# 82     27   4.000000   8.0   8.489362  7.590909   7.0   8.000000
# 83     37  10.000000   8.0   8.489362  7.590909   9.0  10.000000
# 84     28   8.164384   9.0   9.000000  7.590909   6.0   8.769231
# 85     29  10.000000   8.6   8.489362  8.000000   7.0   5.000000
#
# [86 rows x 7 columns]

# %% [markdown]
# # Filling missing values in the dataframe with column means with null values

# %%
#Rounding-off the Scores
columns_to_round = ['Qus1', 'Qus2', 'Qus3', 'Qus4', 'Qus5', 'Qus6']
df[columns_to_round] = df[columns_to_round].round()
df.head()
# Out:
#    Total  Qus1  Qus2  Qus3  Qus4  Qus5  Qus6
# 0     37   9.0  10.0   3.0   8.0   8.0  10.0
# 1     32   7.0   7.0   8.0   9.0   9.0   9.0
# 2     33   9.0   6.0  10.0   8.0   8.0   9.0
# 3     24  10.0   9.0   4.0   8.0   8.0   9.0
# 4     36   9.0   8.0   9.0   8.0  10.0   9.0

# %% [markdown]
# # Rounding values in specific question columns

# %%
#Averge for each Questions
average_scores = df[['Qus1', 'Qus2', 'Qus3', 'Qus4', 'Qus5', 'Qus6']].mean()
print(average_scores)
# Out:
# Qus1    8.139535
# Qus2    8.674419
# Qus3    8.267442
# Qus4    7.895349
# Qus5    8.000000
# Qus6    8.930233
# dtype: float64

# %% [markdown]
# # Calculating and printing average scores for each question

# %%
#toppers for each Questin
toppers = {}
for col in ['Qus1',
            'Qus2',
            'Qus3',
            'Qus4',
            'Qus5',
            'Qus6']:
    toppers[col] = df[df[col] == df[col].max()].index.tolist()

print("Toppers as per each Question:", toppers)
# Out:
# Toppers as per each Question: {'Qus1': [3, 5, 7, 14, 21, 26, 32, 35, 40, 42, 53, 65, 67, 68, 70, 73, 80, 83, 85], 'Qus2': [0, 5, 7, 10, 13, 16, 17, 19, 28, 32, 33, 35, 36, 37, 38, 40, 42, 45, 46, 47, 49, 51, 53, 55, 59, 61, 62, 64, 65, 68, 70, 71, 74, 78], 'Qus3': [2, 6, 9, 15, 20, 21, 24, 27, 28, 33, 36, 42, 45, 46, 47, 49, 50, 53, 54, 59, 62, 64, 65, 70, 71, 73, 78], 'Qus4': [15, 33, 47, 51, 56, 57, 72], 'Qus5': [4, 28, 32, 36, 37, 44, 47, 49, 51, 53, 55, 59, 65, 67, 73], 'Qus6': [0, 9, 10, 15, 17, 26, 33, 50, 54, 55, 56, 59, 61, 73, 81, 83]}

# %% [markdown]
# # Identifying and printing toppers for each question based on maximum scores

# %%
#Bar-Chart that how scores Awarded  
import matplotlib.pyplot as plt
df['Total'].plot(kind='hist', bins=10, color='maroon', edgecolor='blue', alpha=0.7)
plt.title("How scores are awarded")
plt.xlabel("Scores")
plt.ylabel("Reach")
plt.show()

# %% [markdown]
# # Creating a histogram to visualize the distribution of 'Total' scores

# %%
#Bar-Chart Average Scores for Questions
average_scores = df[['Qus1', 'Qus2', 'Qus3', 'Qus4', 'Qus5', 'Qus6']].mean()
average_scores.plot(kind='bar', color='orange', edgecolor='green')
plt.title("Average per Question")
plt.xlabel("Question numbers")
plt.ylabel("Average Score")
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Creating a bar chart to display average scores per question

# %%
#Bar-Plot for Scores in Total column
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.barplot(x=df.index, y="Total", data=df, palette="coolwarm")
plt.title("Scores of each Students") 
plt.xlabel("Student Id")
plt.ylabel("Scores")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Naren\AppData\Local\Temp\ipykernel_10108\272704612.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df.index, y="Total", data=df, palette="coolwarm")

# %% [markdown]
# # Creating a bar plot to visualize total scores for each student

# %%
#Boxplot for Score Distribution
sns.boxplot(data=df[['Qus1', 'Qus2', 'Qus3', 'Qus4', 'Qus5', 'Qus6']])
plt.title("Score Spread per Question") 
plt.xlabel("Questions")
plt.ylabel("Scores")
plt.show()

# %% [markdown]
# # Creating a boxplot to visualize the score distribution per question

# %%
#Correlation Matrix
plt.figure(figsize=(10, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# # Creating a heatmap to visualize the correlation matrix of the dataframe

# %%
df.plot()
plt.show()

# %% [markdown]
# # Plotting all columns in the dataframe for visualization

# %%
#Scatter graph for Question-1
df.plot.scatter(x = 'Qus1', y = 'Total',color='blue',s=30)
plt.title("Scatter Plot for Qus1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Qus1')

# %% [markdown]
# # Creating a scatter plot for 'Qus1' vs 'Total' scores

# %%
#Distribution marks scored in Question1
plt.hist(df['Qus1'],color='red',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Qus1")
plt.ylabel("Students")
plt.title("Histogram of Qus1")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus1')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus1'

# %%
#Distribution marks scored in Question2
plt.hist(df['Qus2'],color='red',edgecolor='white',bins=9)
plt.xlabel("Marks scored in Qus2")
plt.ylabel("Students")
plt.title("Histogram of Qus2")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus2')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus2'

# %%
#Distribution marks scored in Question3
plt.hist(df["Qus3"],color='red',bins=10,edgecolor='green')
plt.xlabel("Marks scored in Qus3")
plt.ylabel("Students")
plt.title("Histogram of Qus3")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus3')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus3

# %%
#Distribution marks scored in Question4
plt.hist(df["Qus4"],color='red',bins=10,edgecolor='grey')
plt.xlabel("Marks scored in Qus4")
plt.ylabel("Students")
plt.title("Histogram of Qus4")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus4')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus4'

# %%
#Distribution marks scored in Question5
plt.hist(df["Qus5"],color='red',bins=10,edgecolor='blue')
plt.xlabel("Marks scored in Qus5")
plt.ylabel("Students")
plt.title("Histogram of Qus5")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus5')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus5'

# %%
#Distribution marks scored in Question6
plt.hist(df["Qus6"],color='red',bins=10,edgecolor='brown')
plt.xlabel("Marks scored in Qus6")
plt.ylabel("Students")
plt.title("Histogram of Qus6")
# Out:
# Text(0.5, 1.0, 'Histogram of Qus6')

# %% [markdown]
# # Creating a histogram to visualize the distribution of marks in 'Qus6'

# %%
#Pie-Chart for Question-wise Average Scores
average_scores = df.iloc[:, 1:].mean()
plt.figure(figsize=(8, 8))
plt.pie(average_scores, labels=average_scores.index, autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Question-Wise Average Scores")
plt.show()

# %% [markdown]
# # Creating a pie chart to show the percentage of average scores per question

# %% [markdown]
# # THANK YOU
